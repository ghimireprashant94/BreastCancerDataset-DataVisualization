# %% [markdown]
# # Data Science and Big Data Analysis (COSC 5340)

# %% [markdown]
# # Prashant R. Ghimire (L20465640)

# %% [markdown]
# Background: There are 10 predictors, all quantitative, and a binary dependent variable, indicating the presence or absence of breast cancer. The predictors are anthropometric data and parameters which can be gathered in routine blood analysis.

# %% [markdown]
# Attribute Information:
#
# Quantitative Attributes:
#     1. Age (years)
#     2. BMI (kg/m2)
#     3. Glucose (mg/dL)
#     4. Insulin (µU/mL)
#     5. HOMA
#     6. Leptin (ng/mL)
#     7. Adiponectin (µg/mL)
#     8. Resistin (ng/mL)
#     9. MCP-1(pg/dL)
#
# Labels:
#     1=Healthy controls
#     2=Patients
#
# Since the data contains no missing information and all the attributes are of the datatype 'integer' or 'float', no preprocessing was performed on this dataset. Although this dataset does require preprocessing, due to the time constraint I couldn't peform it.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
data = pd.read_csv("data.csv")

# %%
#Gives the total number of objects and the attributes

data.shape
# Out:
# (116, 10)

# %%
#Gives the data types of the attributes

data.dtypes
# Out:
# Age                 int64
# BMI               float64
# Glucose             int64
# Insulin           float64
# HOMA              float64
# Leptin            float64
# Adiponectin       float64
# Resistin          float64
# MCP.1             float64
# Classification      int64
# dtype: object

# %%
#Gives the sample of the table from the top

data.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
#Gives the sample of the table from the bottom

data.tail()
# Out:
#      Age    BMI  Glucose  Insulin      HOMA  Leptin  Adiponectin  Resistin  \
# 111   45  26.85       92     3.33  0.755688   54.68        12.10     10.96
# 112   62  26.84      100     4.53  1.117400   12.45        21.42      7.32
# 113   65  32.05       97     5.73  1.370998   61.48        22.54     10.33
# 114   72  25.59       82     2.82  0.570392   24.96        33.75      3.27
# 115   86  27.18      138    19.91  6.777364   90.28        14.11      4.35
#
#       MCP.1  Classification
# 111  268.23               2
# 112  330.16               2
# 113  314.05               2
# 114  392.46               2
# 115   90.09               2

# %%
data_col1 = data['Age']

data_col2 = data['BMI']

data_col3 = data['Glucose']

data_col4 = data['Insulin']

data_col5 = data['HOMA']

data_col6 = data['Leptin']

data_col7 = data['Adiponectin']

data_col8 = data['Resistin']

data_col9 = data['MCP.1']

# %%
new_data = pd.DataFrame(data)

new_data = new_data.drop("Classification",axis=1)


# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x116dfded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117130f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117168d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1171a4ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1171df890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117217890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117251a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117289c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1172c1dd0>]],
#       dtype=object)

# %%
new_data.describe()
# Out:
#               Age         BMI     Glucose     Insulin        HOMA      Leptin  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    57.301724   27.582111   97.793103   10.012086    2.694988   26.615080
# std     16.112766    5.020136   22.525162   10.067768    3.642043   19.183294
# min     24.000000   18.370000   60.000000    2.432000    0.467409    4.311000
# 25%     45.000000   22.973205   85.750000    4.359250    0.917966   12.313675
# 50%     56.000000   27.662416   92.000000    5.924500    1.380939   20.271000
# 75%     71.000000   31.241442  102.000000   11.189250    2.857787   37.378300
# max     89.000000   38.578759  201.000000   58.460000   25.050342   90.280000
#
#        Adiponectin    Resistin        MCP.1
# count   116.000000  116.000000   116.000000
# mean     10.180874   14.725966   534.647000
# std       6.843341   12.390646   345.912663
# min       1.656020    3.210000    45.843000
# 25%       5.474282    6.881763   269.978250
# 50%       8.352692   10.827740   471.322500
# 75%      11.815970   17.755207   700.085000
# max      38.040000   82.100000  1698.440000

# %%
df = pd.DataFrame(new_data)

# %%
scatter_matrix(df, alpha=0.2, figsize=(20, 10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11747ec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1175cdfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1175f9d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117630b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11766b910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1176a66d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1176e2450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11771f210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11774ef90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117787d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1177c1b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1177ff8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117839690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117873450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1178b0210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1178e0f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117919d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117955b10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11798f8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1179c9690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a094d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a41690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a79850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ab0a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117aeabd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b22d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b59f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117b9d150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117bd7310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117c0e4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117c46690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117c7f850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117cb7a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117cf0bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d29d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d64f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117da8150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ddf310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e174d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e50690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e87850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ec0a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ef8bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f31d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f6af50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117fae150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117fe8310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11801f290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118057450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11808f610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1180c87d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118100990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118139b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118173d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1181aaed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1181ed0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118226290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11825d450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118296610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1182d17d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118308990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11833fb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11837bd10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1183b5ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1183f80d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118431290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118468450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11849f610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1184da7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118512990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11854ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118583d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1185bded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1185ff0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118638290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118670450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186a9610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186e17d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11871c990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118754b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11878cd10>]],
#       dtype=object)

# %%
boxplot = df.boxplot(column=['Age', 'BMI', 'Glucose', 'Insulin'
                             ,'HOMA', 'Leptin','Adiponectin','Resistin','MCP.1'])

# %%
plt.plot(data_col1, data_col2, color='blue')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('Age vs BMI')
plt.show()

# %%
plt.plot(data_col1, data_col3, color='green')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.title('Age vs Glucose')
plt.show()
